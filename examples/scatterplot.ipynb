# %% [markdown]
# # Here are some examples of scatterplot functionality...

# %%
import avt
import numpy as np
from sklearn.datasets import load_iris
from matplotlib import animation

# %%
data_dict = load_iris(as_frame=True)

# %%
data, target = data_dict['data'], data_dict['target']
data['target'] = target
data['random group'] = np.random.choice(2, size=len(data))

# %%
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target  random group
# 0       0             1
# 1       0             1
# 2       0             0
# 3       0             1
# 4       0             0

# %% [markdown]
# ## Scatterplot:

# %%
ax = avt.scatter3dplot(
    data=data,
    x='sepal length (cm)',
    y='sepal width (cm)',
    z='petal length (cm)',
    hue='target',
    size='petal width (cm)',
    style='random group',
    cmap='brg'
    )

# saving graph
ax.figure.savefig('./figures/scatter3dplot.png', bbox_inches='tight', dpi=300)
ax.figure.savefig('../docs/source/figures/scatter3dplot.png', bbox_inches='tight', dpi=300)

# %%
ani = animation.FuncAnimation(
    ax.figure, 
    lambda x: ax.view_init(30,x), 
    frames=np.linspace(1,360,90), 
    interval=1, 
    blit=False,
    )
ax.figure.tight_layout()

writergif = animation.PillowWriter(fps=10)

ani.save('./figures/scatter3dplot.gif', writer=writergif, dpi=300)
ani.save('../docs/source/figures/scatter3dplot.gif', writer=writergif, dpi=300)
